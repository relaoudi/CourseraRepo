# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **EL AOUDI REDOUANE**<br>
# I'am a civil engineer dealing with drinking water project to supply cities

# %% [markdown]
# *I am interested in data science because every day I'am faced to process and interpret data for stakehlders*

# %% [markdown]
# <h3>My code below tries to create a graphical representation of the sinx function</h3>

# %%
import numpy as np
from matplotlib import pyplot as plt
x=np.linspace(-2*np.pi,2*np.pi,1000)
y=np.sin(x)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The function sinx is:
# * trigonometric function
# * periodic
# <hr style="border:1px solid blue">
# <ol> In addition:
#     <li>less or equal then 1</li>
#     <li>less or equal then -1</li>
#     </ol><br>
#
#     ~~greater than 100~~<br>

# %% [markdown]
# |x|sinx|
# |---|---|
# |0|0|
# |pi/2|1|
